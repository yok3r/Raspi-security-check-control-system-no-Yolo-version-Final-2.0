# %%
import cv2
import numpy as np
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
import time

# %%
def showImg(img, title = ''):
    plt.figure(figsize = (10,10));
    plt.title(title)
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

def showGrayScaleImg(img, title = ''):
    plt.figure(figsize = (10,10));
    plt.title(title)
    plt.imshow(img, cmap='gray')

all_contours = -1
green = (0,255,0)
thickness = 2

# %%
#load the model
with open('cnn_model_450_Jan.pkl', 'rb') as p_f:
    model = pickle.load(p_f)
# Out:
# Using TensorFlow backend.
# /Users/yok3r/anaconda3/envs/AkademyAI/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/yok3r/anaconda3/envs/AkademyAI/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/yok3r/anaconda3/envs/AkademyAI/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/yok3r/anaconda3/envs/AkademyAI/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/yok3r/anaconda3/envs/AkademyAI/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/yok3r/anaconda3/envs/AkademyAI/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /Users/yok3r/anaconda3/envs/AkademyAI/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/yok3r/anaconda3/envs/AkademyAI/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
image_template = cv2.imread('edgar.jpeg')

# %%
img = cv2.resize(image_template, (450,450))
#img = np.resize(img, (450,450,3))
im2arr = np.array(img)
im2arr1 = im2arr.reshape(1,450,450,3)

# %%
predictions = model.predict(im2arr1)
#predictions = predictions[0][0]
predictions
    
print(predictions)    
print (text)
# Out:
# [[2.8342487e-05 1.5578918e-04 9.9981588e-01]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-be6b85ced416> in <module>
#       4
#       5 print(predictions)
# ----> 6 print (text)
#
# NameError: name 'text' is not defined

# %%
cap = cv2.VideoCapture(0)
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
i=0
while True:

    # Get webcam images
    ret, frame = cap.read()

    height, width = frame.shape[:2]

    top_left_x = width // 3
    top_left_y = (height // 2) + (height // 4)
    bottom_right_x = (width // 3) * 2
    bottom_right_y = (height // 2) - (height // 4)

    faces = face_classifier.detectMultiScale(frame, 1.3, 5)
    #print(faces)
    
    for (x,y,w,h) in faces:
    
        

        magin = 100
        top_left_x = x-magin
        top_left_y = y-magin
        bottom_right_x = x+w+magin
        bottom_right_y = y+w+magin


        cropped = frame[top_left_y:bottom_right_y, top_left_x:bottom_right_x]
        i+=1
        cv2.imwrite('save/eva'+str(i)+'.jpeg',cropped)
        cv2.rectangle(frame, (x,y),(x+w,y+w), (127,0,255), 2)
        
        try:
            #color_eva= cv2.cvtColor(cropped,cv2.COLOR_BGR2RGB)
            
            img = cv2.resize(cropped, (450,450))
            #img = np.resize(img, (450,450,3))
            im2arr = np.array(img)
            im2arr1 = im2arr.reshape(1,450,450,3)

            

            time.sleep(0.005) 
            predictions = model.predict(im2arr1)
            print(predictions)
            text = str(predictions)
            """
            if predictions < 0.0000001:
                text = "EDGAR"
            elif predictions > 0.99999:
                text = "EVA"
            else:
                text = "patata"
            """
            text_pred = str(predictions)
            cv2.putText(frame,text,(30,70), cv2.FONT_HERSHEY_COMPLEX, 0.6 ,(255,255,255), 3)
            #cv2.putText(frame,text_pred,(30,110), cv2.FONT_HERSHEY_COMPLEX, 2 ,(255,255,255), 6)
            
        except Exception as e:
            print(str(e))

        
    ####
    #DETECTTION CODE
    ####
    cv2.imshow('Object Detector using ORB', frame)
    
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break

cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# [[3.521979e-20 2.467858e-23 1.000000e+00]]
# [[3.138860e-23 1.362664e-13 1.000000e+00]]
# [[2.4389298e-23 6.2044185e-12 1.0000000e+00]]
# [[1.7166160e-24 2.5209084e-12 1.0000000e+00]]
# [[1.0411712e-26 1.8283825e-15 1.0000000e+00]]
# [[8.3432714e-24 2.0402131e-12 1.0000000e+00]]
# [[1.7154713e-23 1.7608111e-12 1.0000000e+00]]
# [[3.2616033e-18 4.6789776e-22 1.0000000e+00]]
# [[1.2513543e-18 5.0188501e-23 1.0000000e+00]]
# [[9.980554e-33 9.894361e-16 1.000000e+00]]
# [[1.4775495e-22 8.2640736e-26 1.0000000e+00]]
# [[4.9367635e-23 3.5964762e-12 1.0000000e+00]]
# [[2.0898872e-07 2.7596606e-19 9.9999976e-01]]
# [[1.3319958e-11 1.2895490e-13 1.0000000e+00]]
# [[4.6639206e-14 1.7367132e-15 1.0000000e+00]]
# [[1.1644381e-08 1.7537059e-19 1.0000000e+00]]
# [[7.6794585e-27 8.3626785e-16 1.0000000e+00]]
# [[5.3710376e-18 7.4330305e-19 1.0000000e+00]]
# [[1.04084213e-10 7.50783181e-20 1.00000000e+00]]
# [[9.510732e-18 3.714879e-25 1.000000e+00]]
# [[9.8903612e-16 6.6185535e-16 1.0000000e+00]]
# [[6.1338956e-10 3.8803377e-31 1.0000000e+00]]
# [[1.2770846e-14 1.5353224e-32 1.0000000e+00]]
# [[5.7349586e-18 5.7147216e-38 1.0000000e+00]]
# [[7.8045732e-16 2.0019456e-28 1.0000000e+00]]
# [[2.7730810e-14 4.6312413e-31 1.0000000e+00]]
# [[8.7046755e-15 2.0022914e-26 1.0000000e+00]]
# [[1.8338094e-08 7.4393787e-28 1.0000000e+00]]
# [[1.3612962e-15 9.0365702e-28 1.0000000e+00]]
# [[6.8370905e-17 1.5405975e-31 1.0000000e+00]]
# [[3.3768114e-12 1.0270313e-30 1.0000000e+00]]
# [[3.0502233e-06 3.2612392e-29 9.9999690e-01]]
# [[2.0618798e-02 5.6953789e-32 9.7938126e-01]]
# [[2.2244935e-03 3.3429088e-30 9.9777550e-01]]
# [[5.3671586e-21 2.7856031e-36 1.0000000e+00]]
# [[7.7306265e-28 8.1172247e-19 1.0000000e+00]]
# [[3.2074940e-21 1.2060557e-22 1.0000000e+00]]
# [[7.1740742e-16 4.0987906e-08 1.0000000e+00]]
# [[8.982079e-15 1.574349e-04 9.998425e-01]]
# [[2.0953146e-12 1.6213928e-12 1.0000000e+00]]
# [[8.000511e-16 7.493548e-29 1.000000e+00]]
# [[1.6027080e-08 5.6845173e-32 1.0000000e+00]]
# [[8.3484487e-08 1.3012594e-22 9.9999988e-01]]
# [[5.2089804e-09 1.4517677e-26 1.0000000e+00]]
# [[9.3024095e-09 9.0179451e-27 1.0000000e+00]]
# [[5.4689035e-14 1.5290980e-24 1.0000000e+00]]
# [[2.088115e-18 4.239172e-27 1.000000e+00]]
# [[4.642863e-16 6.923249e-26 1.000000e+00]]
# [[2.2086547e-06 1.2225237e-16 9.9999774e-01]]
# [[4.0945585e-04 4.0388641e-24 9.9959058e-01]]
# [[2.1951006e-08 1.5414057e-20 1.0000000e+00]]
# [[1.7378877e-06 3.5798265e-19 9.9999821e-01]]
# [[7.5486454e-04 4.7939742e-12 9.9924517e-01]]
# [[9.8268008e-13 2.4831347e-25 1.0000000e+00]]
# [[8.7275449e-04 1.5527404e-16 9.9912721e-01]]
# [[2.487732e-05 2.844586e-19 9.999751e-01]]
# [[5.6126366e-09 6.9303164e-15 1.0000000e+00]]
# [[7.1766693e-10 4.9106947e-15 1.0000000e+00]]
# [[3.2720611e-05 5.2574280e-17 9.9996734e-01]]
# [[2.6122149e-07 6.3799802e-14 9.9999976e-01]]
# [[1.2615515e-14 7.6288476e-11 1.0000000e+00]]
# [[1.6752743e-06 1.0210969e-20 9.9999833e-01]]
# [[2.8175496e-19 7.9680880e-20 1.0000000e+00]]
# [[1.3707063e-06 2.5679433e-17 9.9999869e-01]]
# [[5.6570986e-13 2.0881597e-21 1.0000000e+00]]
# [[1.09407600e-12 1.34269635e-11 1.00000000e+00]]
# [[4.4129692e-06 4.9440214e-21 9.9999559e-01]]
# [[1.3779737e-03 9.9860746e-01 1.4644103e-05]]
# [[8.2823826e-10 2.0958500e-16 1.0000000e+00]]
# [[9.7633410e-01 2.3665097e-02 8.6400195e-07]]
# [[1.9334753e-11 1.1885836e-18 1.0000000e+00]]
# [[9.4665605e-01 5.3332686e-02 1.1324279e-05]]
# [[9.624421e-01 3.748146e-02 7.644041e-05]]
# [[4.1764103e-09 6.7842530e-30 1.0000000e+00]]
# [[7.1816635e-01 2.8153673e-01 2.9692627e-04]]
# [[2.3264736e-05 0.0000000e+00 9.9997675e-01]]
# [[9.9925834e-01 5.2217144e-04 2.1947284e-04]]
# [[1.06774815e-11 0.00000000e+00 1.00000000e+00]]
# [[9.4709033e-01 5.2834943e-02 7.4705960e-05]]
# [[2.3661086e-01 7.6285541e-01 5.3380895e-04]]
# [[1.3909038e-12 0.0000000e+00 1.0000000e+00]]
# [[2.3754979e-02 9.7624469e-01 3.2356905e-07]]
# [[0.11717338 0.63539785 0.24742877]]
# [[2.4159991e-03 9.9758255e-01 1.4068770e-06]]
# [[9.3474621e-03 9.9065125e-01 1.2569055e-06]]
# [[3.6957242e-06 9.9999630e-01 3.4776104e-08]]
# [[1.9416603e-03 9.9805814e-01 9.8518967e-08]]
# [[1.7748378e-01 8.2251507e-01 1.1289279e-06]]
# [[4.8210356e-01 5.1789463e-01 1.8181985e-06]]
# [[2.092737e-02 9.790637e-01 8.863033e-06]]
# [[9.4844013e-01 5.1556487e-02 3.3709689e-06]]
# [[9.9996889e-01 6.2472900e-06 2.4909214e-05]]
# [[9.9998367e-01 3.0919750e-07 1.6028478e-05]]
# [[9.9997377e-01 3.9067447e-10 2.6232537e-05]]
# [[9.9971300e-01 1.3230218e-10 2.8702590e-04]]
# [[9.9958795e-01 2.4782346e-12 4.1204385e-04]]
# [[9.9936169e-01 7.0339845e-10 6.3827127e-04]]
# [[9.9994314e-01 8.2844498e-15 5.6806301e-05]]
# [[9.9804938e-01 2.0366213e-05 1.9302805e-03]]
# [[9.9898356e-01 2.3155037e-05 9.9325564e-04]]
# [[9.9853158e-01 5.9311245e-05 1.4091808e-03]]
# [[9.4427693e-01 3.5892150e-05 5.5687122e-02]]
# [[9.6575171e-01 8.7843844e-16 3.4248274e-02]]
# [[4.5041852e-03 2.7425634e-10 9.9549580e-01]]
# [[1.0973316e-09 1.1377953e-24 1.0000000e+00]]
# [[9.7661257e-01 2.2121981e-11 2.3387423e-02]]
# OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/imgproc/src/resize.cpp:4044: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# [[6.9892565e-05 1.2724203e-13 9.9993014e-01]]
# [[7.9379016e-01 6.3052918e-10 2.0620978e-01]]
# [[9.2070877e-05 6.5050119e-07 9.9990726e-01]]
# [[1.1539318e-04 8.8546640e-04 9.9899918e-01]]
# [[1.9655641e-08 2.9543840e-04 9.9970454e-01]]
# [[0.00549733 0.09041458 0.904088  ]]
# [[2.1524700e-04 5.4992183e-10 9.9978477e-01]]
# [[9.2173618e-04 2.3077762e-10 9.9907827e-01]]
# [[1.7479638e-04 8.9930469e-01 1.0052058e-01]]
# [[8.664638e-06 7.048390e-07 9.999906e-01]]
# [[1.379537e-04 9.305403e-09 9.998621e-01]]
# [[1.0155480e-04 2.7221728e-03 9.9717629e-01]]
# [[1.5349725e-09 5.2680451e-05 9.9994731e-01]]
# [[3.30027433e-07 1.16030894e-01 8.83968771e-01]]
# [[6.6912185e-07 1.5414825e-03 9.9845791e-01]]
# [[1.6907185e-16 0.0000000e+00 1.0000000e+00]]
# [[6.9668555e-01 1.1471189e-11 3.0331451e-01]]
# [[5.1026745e-08 1.2529556e-04 9.9987459e-01]]
# [[7.4005447e-02 6.2833001e-06 9.2598826e-01]]
# [[1.5877944e-07 9.7966230e-01 2.0337567e-02]]
# [[4.845822e-04 8.590665e-08 9.995153e-01]]
# [[9.9798592e-05 9.9429816e-01 5.6020124e-03]]
# [[2.9515555e-02 8.0326427e-05 9.7040415e-01]]
# [[9.7491145e-01 7.5452181e-06 2.5080999e-02]]
# [[8.2311878e-04 9.8228341e-01 1.6893514e-02]]
# [[0.0612328  0.05812194 0.88064533]]
# [[9.9999809e-01 2.6148396e-11 1.8606959e-06]]
# [[0.00294904 0.21281487 0.7842361 ]]
# [[9.8456776e-01 2.9655875e-04 1.5135692e-02]]
# [[9.999896e-01 3.056221e-07 9.961093e-06]]
# [[1.0000000e+00 3.0204502e-11 3.1128831e-08]]
# [[0.00116521 0.1053344  0.8935004 ]]
# [[0.03494957 0.29384443 0.67120594]]
# OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/imgproc/src/resize.cpp:4044: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/imgproc/src/resize.cpp:4044: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/imgproc/src/resize.cpp:4044: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/imgproc/src/resize.cpp:4044: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/imgproc/src/resize.cpp:4044: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/imgproc/src/resize.cpp:4044: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/imgproc/src/resize.cpp:4044: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/imgproc/src/resize.cpp:4044: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/imgproc/src/resize.cpp:4044: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# [[0.01981883 0.96018255 0.01999855]]
# OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/imgproc/src/resize.cpp:4044: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/imgproc/src/resize.cpp:4044: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/imgproc/src/resize.cpp:4044: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# -1
